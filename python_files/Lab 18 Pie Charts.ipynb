# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 188.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 191.4 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 164.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 163.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 94.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 154.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-02-26 21:16:42--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  66.7MB/s    in 2.3s
#
# 2025-02-26 21:16:45 (66.7 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here
database_counts = df['DatabaseWantToWorkWith'].value_counts()

# Select the top 5 databases
top5_databases = database_counts.head(5)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top5_databases.values, labels=top5_databases.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'orange', 'lightcoral', 'lightyellow'])

# Set plot title
plt.title('Top 5 Databases Respondents Want to Work With', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
DevType_counts = df['DevType'].value_counts()

top5_devtype = DevType_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top5_devtype.values, labels=top5_devtype.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'orange', 'lightcoral', 'lightyellow'])

# Set plot title
plt.title('Top 5 developer types for Respondent', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
##Write your code here
OpSysProfessional_counts = df['OpSysProfessional use'].value_counts()
top5_OpSysProfessional = OpSysProfessional_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top5_OpSysProfessional.values, labels=top5_OpSysProfessional.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'orange', 'lightcoral', 'lightyellow'])

# Set plot title
plt.title('Top 5 Operating systems', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
LanguageHaveWorkedWith_counts = df['LanguageHaveWorkedWith'].value_counts()
top5_LanguageHaveWorkedWith = LanguageHaveWorkedWith_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top5_LanguageHaveWorkedWith.values, labels=top5_LanguageHaveWorkedWith.index, autopct='%1.1f%%', startangle=140)

# Set plot title
plt.title('Top 5 programming languages that respondents have experience with', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here

NEWCollabToolsHaveWorkedWith_counts = df['NEWCollabToolsHaveWorkedWith'].value_counts()
top5_NEWCollabToolsHaveWorkedWith = NEWCollabToolsHaveWorkedWith_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top5_NEWCollabToolsHaveWorkedWith.values, labels=top5_NEWCollabToolsHaveWorkedWith.index, autopct='%1.1f%%', startangle=140)

# Set plot title
plt.title('Top collaboration tools respondents use in their professional work', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here

LanguageAdmired_counts = df['LanguageAdmired'].value_counts()
top5_LanguageAdmired = LanguageAdmired_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top5_LanguageAdmired.values, labels=top5_LanguageAdmired.index, autopct='%1.1f%%', startangle=140)

# Set plot title
plt.title('Programming languages respondents admire most', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
AIToolCurrently_counts = df['AIToolCurrently Using'].value_counts()
top5_AIToolCurrently = AIToolCurrently_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top5_AIToolCurrently.values, labels=top5_AIToolCurrently.index, autopct='%1.1f%%', startangle=140)

# Set plot title
plt.title('Top 5 tools developers are currently using for AI development', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_299/2544719442.py:12: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
WebframeWantToWorkWith_counts = df['WebframeWantToWorkWith'].value_counts()
top5_WebframeWantToWorkWith = WebframeWantToWorkWith_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top5_WebframeWantToWorkWith.values, labels=top5_WebframeWantToWorkWith.index, autopct='%1.1f%%', startangle=140)

# Set plot title
plt.title('Web frameworks that respondents are interested in working with', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
EmbeddedWantToWorkWith_counts = df['EmbeddedWantToWorkWith'].value_counts()
top5_EmbeddedWantToWorkWith = EmbeddedWantToWorkWith_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top5_EmbeddedWantToWorkWith.values, labels=top5_EmbeddedWantToWorkWith.index, autopct='%1.1f%%', startangle=140)

# Set plot title
plt.title('Top 5 most desired embedded technologies that respondents wish to work with', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
